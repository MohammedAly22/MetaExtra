# %%
## Before starting :-
 #Convert the paper into a text (ignoring scientific images , references , margins)
 #Then open the text & read it


Text = open (r"C:\Users\Salma\Documents\manual_processed_text.txt", "r")
the_text = Text.read()
print(the_text)
# Out:
# Endangered wild salmon infected by
# newly discovered viruses
#
# Kristina M Miller,Karia H Kaukinen,Shaorong Li,
# Amy Tabata, Amy Teffer,Hugh W Ferguson.
#
# 1Department of Earth, Ocean and Atmospheric Sciences, University of British
# Columbia, Vancouver, Canada;2Pacific Biological Station, Fisheries and
# Nanaimo, Canada;3Pacific Salmon Foundation, Vancouver, Canada;
# 4Department of Forest Sciences, University of British Columbia, Vancouver, Canada;
# 5Fisheries and Cooperative Resource Management
# Institute, School of Resource and Environmental Management, Simon Fraser
# University, Burnaby, Canada;6School of Veterinary Medicine, St. Georgeâ€™s
# University, True Blue, Grenada;7Department of Microbiology and Immunology,
# University of British Columbia, Vancouver, Canada;8Department of Botany,
# University of British Columbia, Vancouver, Canada;9Institute for the Oceans and
# Fisheries, University of British Columbia, Vancouver, Canada
# ...

# %%
#Extract Authors Names

import nltk
from nameparser.parser import HumanName
from nltk.corpus import wordnet


person_list = []
person_names=person_list
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos, binary = False)

    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []
        
spl_wordd = "."
 
the_small_text = the_text.partition(spl_wordd)[0]
 
#print(the_small_text)

names = get_human_names(the_small_text)
for person in person_list:
    person_split = person.split(" ")
print ('Authors :-')    
print(person_names)
# Out:
# Authors :-
# ['Kristina M Miller', 'Karia H Kaukinen', 'Shaorong Li', 'Amy Tabata', 'Amy Teffer', 'Hugh W Ferguson']

# %%
print (person_names[0])
# Out:
# Kristina M Miller

# %%
# Extract title
  ##By split the text into 2 parts 
  ## the part that endby the first author name is the title
 

spl_word = person_names[0]
 
the_title = the_text.partition(spl_word)[0]
print('The title :-') 
print(the_title)
# Out:
# The title :-
# Endangered wild salmon infected by
# newly discovered viruses

# %%
# Extract Keywords
print ('Key words :-')
import yake
kw_extractor = yake.KeywordExtractor(top=10, stopwords=None)
keywords = kw_extractor.extract_keywords(the_text)
for kw, v in keywords:
    print("Keyphrase: ",kw, ": score", v)
# Out:
# Key words :-
# Keyphrase:  salmon : score 0.0027937635769258395
# Keyphrase:  Pacific salmon : score 0.003473628989064994
# Keyphrase:  wild salmon : score 0.004565260906188561
# Keyphrase:  British Columbia : score 0.0049364774440372045
# Keyphrase:  wild salmon populations : score 0.005271339607506885
# Keyphrase:  RNA : score 0.006827364375242002
# Keyphrase:  viruses : score 0.007470188396907857
# Keyphrase:  Chinook salmon : score 0.00852095291846679
# Keyphrase:  sockeye salmon : score 0.010698838668936079
# Keyphrase:  Canada : score 0.013236392129066403
